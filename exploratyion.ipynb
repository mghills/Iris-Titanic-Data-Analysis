# %% [markdown]
# # Introduction to this Project
# The goal of this project is to show familiar with a few very common machine learning algorithms, as well as some basic data analysis. Each dataset is broken down into its own section, both of which start with some quick exploration and plotting. This then leads into creating some form of model for any interesting relationships found in the previous exploration stage. Each section then ends with some basic ratings of these models, using various metrics. The Iris dataset focuses on using linear regressions, as well as looking into some transforms, in order to model relationships between features. The titanic dataset will use some common machine learning classifies, in order to create a prediction of surival based on various factors.

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
import sklearn
import matplotlib.pyplot as plt

iris = pd.read_csv("./datasets/iris.csv")
titanic = pd.read_csv("./datasets/titanic.csv")

# %% [markdown]
# # Iris Dataset

# %% [markdown]
# ### Exploration and Plotting

# %%
print("Iris Dataset:")
iris.head()
# Out:
# Iris Dataset:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# In this next block of code the different iris varieties are split up into groups, and then their sepal width and length are plotted. The variable groups will be useful in a lot of future analysis, as the difference in the groups is very interesting.

# %%
groups = iris.groupby('variety')

# Plot for sepal length and sepal width
for name, group in groups:
    plt.plot(group["sepal.length"], group["sepal.width"], marker='o', linestyle='', markersize=8, label=name)



plt.title("Sepal Width versus Sepal Length for various Iris Varities")
plt.legend()
plt.show()

# Plot for petal length and petal width
for name, group in groups:
    plt.plot(group["petal.length"], group["petal.width"], marker='o', linestyle='', markersize=6, label=name)


plt.title("Petal Width versus Petal Length for various Iris Varities")
plt.legend()
plt.show()

# Plot for sepal length and petal length
for name, group in groups:
    plt.plot(group["petal.length"], group["sepal.length"], marker='o', linestyle='', markersize=6, label=name)


plt.title("Sepal Length versus Petal Length for various Iris Varities")
plt.legend()
plt.show()

# %% [markdown]
# Here we can see that there are a couple interesting relationships we can look at. At a glance we can quickly use the above plots to know which relationships might be good places to start, in terms of creating useful models. For example we already know from these plots that sepal width and sepal length are not very related, at least when not taking into account each flowers variety, if we break these down more there might be useful relationship to look at (more on this later). We can, however, see that without breaking the varieity into seperate groups there are still good relationships to model.

# %%
iris.corr(numeric_only=True)
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000
